# %%
# Imports
import urllib2 as urllib
import json
import pandas
import datetime

# %%
# Download Data
oauth_api_key = '14ce3b2e1d6a7a361a167f2d27c7d69209e39df4'
guid = 'INFRA-31368'

url = 'http://miraflores.cloudapi.junar.com/datastreams/invoke/{0:}?auth_key={1:}&output=json_array'
url = url.format(guid, oauth_api_key)

request = urllib.urlopen(url)

textResponse = request.read()

jsonResponse = json.loads(textResponse)

data = jsonResponse['result']

keys = []

dictData = []

for i, row in enumerate(data):
    if i == 0:
        keys = [item.replace('-', '_') for item in row]

    else:
        dictData.append(dict(zip(keys, row)))

# %%
# Making timeseries
dates = [item[u'FECHA'] + ' ' + item[u'HORA'] for item in dictData]

datesAux = []

for i, item in enumerate(dates):
    try:
        datesAux.append(datetime.datetime.strptime(item, '%d/%m/%Y %H:%M'))
    except:
        pass

dates = datesAux


cumF = 0
cumT = ''

datesAux = []
frecuency = []

def cumulativeFrequency(t):
    global cumF
    global cumT
    
    if cumT != t.replace(minute=0):
        if cumT != '':
            datesAux.append(cumT)
            frecuency.append(cumF)
        
        cumT = t.replace(minute=0)
        cumF = 0
    else:
        cumF = cumF + 1

filter(cumulativeFrequency, dates)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-b960ead32068> in <module>()
#      33         cumF = cumF + 1
#      34
# ---> 35 filter(cumulativeFrequency, dates)
#
# <ipython-input-12-b960ead32068> in cumulativeFrequency(***failed resolving arguments***)
#      19 frecuency = []
#      20
# ---> 21 def cumulativeFrequency( (t, f) ):
#      22     global cumF
#      23     global cumT
#
# TypeError: 'datetime.datetime' object is not iterable

# %%
print datesAux
# Out:
# [datetime.datetime(2014, 1, 16, 15, 54), datetime.datetime(2014, 1, 16, 17, 23), datetime.datetime(2014, 1, 16, 17, 37), datetime.datetime(2014, 1, 16, 18, 58), datetime.datetime(2014, 1, 17, 17, 22), datetime.datetime(2014, 1, 24, 8, 5), datetime.datetime(2014, 1, 24, 12, 23), datetime.datetime(2014, 1, 27, 18, 57), datetime.datetime(2014, 1, 27, 19, 19), datetime.datetime(2014, 1, 28, 20, 47), datetime.datetime(2014, 1, 30, 19, 52), datetime.datetime(2014, 1, 30, 20, 10), datetime.datetime(2014, 1, 30, 20, 14), datetime.datetime(2014, 2, 3, 8, 11), datetime.datetime(2014, 2, 3, 8, 18), datetime.datetime(2014, 2, 3, 8, 30), datetime.datetime(2014, 2, 3, 16, 17), datetime.datetime(2014, 2, 3, 18, 25), datetime.datetime(2014, 2, 4, 8, 57), datetime.datetime(2014, 2, 4, 9, 3), datetime.datetime(2014, 2, 4, 18, 33), datetime.datetime(2014, 2, 4, 18, 39), datetime.datetime(2014, 2, 4, 19, 53), datetime.datetime(2014, 2, 4, 19, 56), datetime.datetime(2014, 2, 5, 8, 15), datetime.datetime(2014, 2, 5, 9, 50), datetime.